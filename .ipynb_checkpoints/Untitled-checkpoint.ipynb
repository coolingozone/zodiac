# %%
import numpy as np
import pandas as pd

df=pd.read_csv('The Zodiac Race Challenge_Dataset.csv')
df.head()
# Out:
#    Desert  Mountain  Water  Land  Forest  Snow  Average_Temperature  \
# 0    7376      4387   7769  7374     814  2677                   18
# 1    7911      5771   4993  1855    9605   283                   18
# 2    8948      9631   1855  4913    3531  3746                   39
# 3    1735      6643   6066  9976    9119  9912                   24
# 4    2001      8287   4062  8763    9751  2820                   26
#
#   Is_Raining Had_A_Good_Sleep Winner  Winner_Time   Second  Second_Time  \
# 0        Yes              Yes    rat          218      dog          242
# 1        Yes              Yes  tiger          216    snake          224
# 2        Yes               No     ox          191   rabbit          217
# 3        Yes               No   goat          319  rooster          322
# 4        Yes              Yes  horse          255     goat          259
#
#      Third  Third_Time
# 0   dragon         245
# 1      rat         239
# 2    horse         240
# 3    horse         334
# 4  rooster         263

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 15 columns):
# Desert                 40000 non-null int64
# Mountain               40000 non-null int64
# Water                  40000 non-null int64
# Land                   40000 non-null int64
# Forest                 40000 non-null int64
# Snow                   40000 non-null int64
# Average_Temperature    40000 non-null int64
# Is_Raining             40000 non-null object
# Had_A_Good_Sleep       40000 non-null object
# Winner                 40000 non-null object
# Winner_Time            40000 non-null int64
# Second                 40000 non-null object
# Second_Time            40000 non-null int64
# Third                  40000 non-null object
# Third_Time             40000 non-null int64
# dtypes: int64(10), object(5)
# memory usage: 4.6+ MB

# %%
df[df['Had_A_Good_Sleep'].where(df['Had_A_Good_Sleep'] == 'ABCDE').notnull()]
# Out:
#        Desert  Mountain  Water  Land  Forest  Snow  Average_Temperature  \
# 24246    6856      4683   1288  2313    1571   355                   13
#
#       Is_Raining Had_A_Good_Sleep Winner  Winner_Time  Second  Second_Time  \
# 24246         No            ABCDE  horse          130  dragon          144
#
#         Third  Third_Time
# 24246  monkey         149

# %%
df.drop(24246, inplace=True)

# %%
df = df.astype({"Desert": float, "Mountain": float,"Water":float,"Land":float,"Forest":float,"Snow":float})

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39999 entries, 0 to 39999
# Data columns (total 15 columns):
# Desert                 39999 non-null float64
# Mountain               39999 non-null float64
# Water                  39999 non-null float64
# Land                   39999 non-null float64
# Forest                 39999 non-null float64
# Snow                   39999 non-null float64
# Average_Temperature    39999 non-null int64
# Is_Raining             39999 non-null object
# Had_A_Good_Sleep       39999 non-null object
# Winner                 39999 non-null object
# Winner_Time            39999 non-null int64
# Second                 39999 non-null object
# Second_Time            39999 non-null int64
# Third                  39999 non-null object
# Third_Time             39999 non-null int64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 4.9+ MB

# %%
from sklearn import preprocessing 
le = preprocessing.LabelEncoder() #create an encoder instance
le.fit(["No", "Yes"])             #fit the encoder with two string "no" and "yes"
print(list(list(le.classes_)))
df['Is_Raining']=le.transform(df['Is_Raining'])    #to transform df['driveway'] value of yes and no to 1 and 0
df['Had_A_Good_Sleep']=le.transform(df['Had_A_Good_Sleep'])    #to transform df['driveway'] value of yes and no to 1 and 0
print(df.head())
# Out:
# ['No', 'Yes']
#    Desert  Mountain   Water    Land  Forest    Snow  Average_Temperature  \
# 0  7376.0    4387.0  7769.0  7374.0   814.0  2677.0                   18
# 1  7911.0    5771.0  4993.0  1855.0  9605.0   283.0                   18
# 2  8948.0    9631.0  1855.0  4913.0  3531.0  3746.0                   39
# 3  1735.0    6643.0  6066.0  9976.0  9119.0  9912.0                   24
# 4  2001.0    8287.0  4062.0  8763.0  9751.0  2820.0                   26
#
#    Is_Raining  Had_A_Good_Sleep Winner  Winner_Time   Second  Second_Time  \
# 0           1                 1    rat          218      dog          242
# 1           1                 1  tiger          216    snake          224
# 2           1                 0     ox          191   rabbit          217
# 3           1                 0   goat          319  rooster          322
# 4           1                 1  horse          255     goat          259
#
#      Third  Third_Time
# 0   dragon         245
# 1      rat         239
# 2    horse         240
# 3    horse         334
# 4  rooster         263

# %%
le2 = preprocessing.LabelEncoder() #create an encoder instance
le2.fit(['rat','ox','tiger','rabbit','monkey','rooster','dog','pig','dragon','snake','horse','goat'])             #fit the encoder with two string "no" and "yes"
print(list(list(le2.classes_)))
df['Winner']=le2.transform(df['Winner'])    #to transform df['driveway'] value of yes and no to 1 and 0
df['Second']=le2.transform(df['Second'])    #to transform df['driveway'] value of yes and no to 1 and 0
df['Third']=le2.transform(df['Third'])    #to transform df['driveway'] value of yes and no to 1 and 0
df.head()
# Out:
# ['dog', 'dragon', 'goat', 'horse', 'monkey', 'ox', 'pig', 'rabbit', 'rat', 'rooster', 'snake', 'tiger']
#    Desert  Mountain   Water    Land  Forest    Snow  Average_Temperature  \
# 0  7376.0    4387.0  7769.0  7374.0   814.0  2677.0                   18
# 1  7911.0    5771.0  4993.0  1855.0  9605.0   283.0                   18
# 2  8948.0    9631.0  1855.0  4913.0  3531.0  3746.0                   39
# 3  1735.0    6643.0  6066.0  9976.0  9119.0  9912.0                   24
# 4  2001.0    8287.0  4062.0  8763.0  9751.0  2820.0                   26
#
#    Is_Raining  Had_A_Good_Sleep  Winner  Winner_Time  Second  Second_Time  \
# 0           1                 1       8          218       0          242
# 1           1                 1      11          216      10          224
# 2           1                 0       5          191       7          217
# 3           1                 0       2          319       9          322
# 4           1                 1       3          255       2          259
#
#    Third  Third_Time
# 0      1         245
# 1      8         239
# 2      3         240
# 3      3         334
# 4      9         263

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import  seaborn as sns
import matplotlib.pyplot as plt

Y = df['Winner']  #price is the target, Y
X=np.array([df['Desert'], df['Mountain'],df['Water'],df['Land'],df['Forest'],df['Snow'],df['Average_Temperature'],df['Is_Raining'],df['Had_A_Good_Sleep']])
X=X.T
for row in X:
    
    total=row[0]+row[1]+row[2]+row[3]+row[4]+row[5]
    row[0]=row[0]/total
    row[1]=row[1]/total
    row[2]=row[2]/total
    row[3]=row[3]/total
    row[4]=row[4]/total
    row[5]=row[5]/total
big=max(X[:,6])
X[:,6]=X[:,6]/big

classifier=SGDClassifier(max_iter=2000)
Xtrain, Xtest, ytrain, ytest=train_test_split(X,Y,random_state=10,test_size=0.2)
classifier.fit(Xtrain,ytrain)
y_pred=classifier.predict(Xtest)
print(accuracy_score(ytest,y_pred))  #percentage of classification on the test data is correct   
mat2=confusion_matrix(ytest,y_pred)
sns.heatmap(mat2,square=True,annot=True,cbar=False,fmt='d')
plt.xlabel('predicted value')
plt.ylabel('true value')
plt.show()
# Out:
# 0.606

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import confusion_matrix


clf = LinearSVC(random_state=20, tol=1e-5)
clf.fit(Xtrain, ytrain)
y_pred=clf.predict(Xtest)

print(accuracy_score(ytest,y_pred))


mat2=confusion_matrix(ytest,y_pred)
sns.heatmap(mat2,square=True,annot=True,cbar=False,fmt='d')
plt.xlabel('predicted value')
plt.ylabel('true value')
plt.show()
# Out:
# 0.71025

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import np_utils
from keras.datasets import mnist
from sklearn.metrics import confusion_matrix
# Out:
# Using TensorFlow backend.

# %%
#  Preprocess class labels
Y_train = np_utils.to_categorical(ytrain, 12)
Y_test = np_utils.to_categorical(ytest, 12)
print(Y_train.shape)

#  Define model architecture

model = Sequential()
model.add(Dense(512, input_shape=(9,)))
model.add(Activation('relu')) # An "activation" is just a non-linear function applied to the output
                              # of the layer above. Here, with a "rectified linear unit",
                              # we clamp all values below 0 to 0.
                           
model.add(Dropout(0.2))   # Dropout helps protect the model from memorizing or "overfitting" the training data
model.add(Dense(1024,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1024,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(12,activation='softmax'))# This special "softmax" activation among other things,
                                 # ensures the output is a valid probaility distribution, that is
                                 # that its values are all non-negative and sum to 1.
# Compile model
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
 
# Fit model on training data

history=model.fit(Xtrain, Y_train,
          batch_size=64, epochs=150)
 
# Evaluate model on test data
score = model.evaluate(Xtest, Y_test, verbose=0)
predictions = model.predict(Xtest)
confusion  = confusion_matrix(Y_test.argmax(axis=1), predictions.argmax(axis=1))
plt.figure(figsize = (5,5))
sns.heatmap(confusion,square=False,annot=True,cbar=False,fmt='d')
plt.xlabel('predicted value')
plt.ylabel('true value')
plt.show()
# Out:
# (31999, 12)
# Epoch 1/150
# 31999/31999 [==============================] - 40s 1ms/step - loss: 1.9713 - acc: 0.2703
# Epoch 2/150
# 31999/31999 [==============================] - 39s 1ms/step - loss: 1.4803 - acc: 0.4304
# Epoch 3/150
# 31999/31999 [==============================] - 42s 1ms/step - loss: 1.2653 - acc: 0.5052
# Epoch 4/150
# 31999/31999 [==============================] - 41s 1ms/step - loss: 1.1514 - acc: 0.5527
# Epoch 5/150
# 31999/31999 [==============================] - 40s 1ms/step - loss: 1.0763 - acc: 0.5767
# Epoch 6/150
# 31999/31999 [==============================] - 38s 1ms/step - loss: 1.0229 - acc: 0.5960
# Epoch 7/150
# 31999/31999 [==============================] - 38s 1ms/step - loss: 0.9767 - acc: 0.6142
# Epoch 8/150
# 31999/31999 [==============================] - 40s 1ms/step - loss: 0.9350 - acc: 0.6298
# Epoch 9/150
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-1b35dad6047d> in <module>()
#      32
#      33 history=model.fit(Xtrain, Y_train,
# ---> 34           batch_size=64, epochs=150)
#      35
#      36 # Evaluate model on test data
#
# c:\users\teokk\appdata\local\programs\python\python35\lib\site-packages\keras\models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1000                               initial_epoch=initial_epoch,
#    1001                               steps_per_epoch=steps_per_epoch,
# -> 1002                               validation_steps=validation_steps)
#    1003
#    1004     def evaluate(self, x=None, y=None,
#
# c:\users\teokk\appdata\local\programs\python\python35\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# c:\users\teokk\appdata\local\programs\python\python35\lib\site-packages\keras\engine\training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1234                         ins_batch[i] = ins_batch[i].toarray()
#    1235
# -> 1236                     outs = f(ins_batch)
#    1237                     if not isinstance(outs, list):
#    1238                         outs = [outs]
#
# c:\users\teokk\appdata\local\programs\python\python35\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2480         session = get_session()
#    2481         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2482                               **self.session_kwargs)
#    2483         return updated[:len(self.outputs)]
#    2484
#
# c:\users\teokk\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# c:\users\teokk\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# c:\users\teokk\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# c:\users\teokk\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# c:\users\teokk\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# c:\users\teokk\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %%
print(accuracy_score(Y_test.argmax(axis=1), predictions.argmax(axis=1)))
real=np.array([[2345], [8764],[6689],[7332],[1050],[3741],[1],[1],[1]])
total=real[0]+real[1]+real[2]+real[3]+real[4]+real[5]
real[0]=real[0]/total
real[1]=real[1]/total
real[2]=real[2]/total
real[3]=real[3]/total
real[4]=real[4]/total
real[5]=real[5]/total
X[:,6]=X[:,6]/40
real=real.T
print(real)
testreal = model.predict(real)
print(testreal.argmax(axis=1))
print(testreal)
# Out:
# 0.792
# [[0 0 0 0 0 0 1 1 1]]
# [7]
# [[2.57176816e-06 7.89143160e-05 4.67976934e-05 3.53771429e-05
#   1.19524088e-08 1.33944169e-01 2.33613357e-01 6.24338686e-01
#   7.92106800e-03 1.91264444e-05 1.02818754e-14 2.60457156e-13]]

# %%
from keras.utils import np_utils
Y = df['Second']  #price is the target, Y
Xtrain, Xtest, ytrain, ytest=train_test_split(X,Y,random_state=10,test_size=0.2)
#  Preprocess class labels
Y_train = np_utils.to_categorical(ytrain, 12)
Y_test = np_utils.to_categorical(ytest, 12)
print(Y_train.shape)

#  Define model architecture

model2 = Sequential()
model2.add(Dense(512, input_shape=(9,)))
model2.add(Activation('relu')) # An "activation" is just a non-linear function applied to the output
                              # of the layer above. Here, with a "rectified linear unit",
                              # we clamp all values below 0 to 0.
                           
model2.add(Dropout(0.2))   # Dropout helps protect the model from memorizing or "overfitting" the training data
model2.add(Dense(512,activation='relu'))
model2.add(Dropout(0.2))
model2.add(Dense(512,activation='relu'))
model2.add(Dropout(0.2))
model2.add(Dense(512,activation='relu'))
model2.add(Dropout(0.2))
model2.add(Dense(12,activation='softmax'))# This special "softmax" activation among other things,
                                 # ensures the output is a valid probaility distribution, that is
                                 # that its values are all non-negative and sum to 1.
# Compile model
model2.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00]]

# %%
Y = df['Third']  #price is the target, Y
Xtrain, Xtest, ytrain, ytest=train_test_split(X,Y,random_state=10,test_size=0.2)
#  Preprocess class labels
Y_train = np_utils.to_categorical(ytrain, 12)
Y_test = np_utils.to_categorical(ytest, 12)
print(Y_train.shape)

#  Define model architecture

model3 = Sequential()
model3.add(Dense(512, input_shape=(9,)))
model3.add(Activation('relu')) # An "activation" is just a non-linear function applied to the output
                              # of the layer above. Here, with a "rectified linear unit",
                              # we clamp all values below 0 to 0.
                           
model3.add(Dropout(0.2))   # Dropout helps protect the model from memorizing or "overfitting" the training data
model3.add(Dense(512,activation='relu'))
model3.add(Dropout(0.2))
model3.add(Dense(512,activation='relu'))
model3.add(Dropout(0.2))
model3.add(Dense(512,activation='relu'))
model3.add(Dropout(0.2))
model3.add(Dense(512,activation='relu'))
model3.add(Dropout(0.2))
model3.add(Dense(12,activation='softmax'))# This special "softmax" activation among other things,
                                 # ensures the output is a valid probaility distribution, that is
                                 # that its values are all non-negative and sum to 1.
# Compile model
model3.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
 
# Fit model on training data

history=model3.fit(Xtrain, Y_train,
          batch_size=128, epochs=120)
 
# Evaluate model on test data
score = model3.evaluate(Xtest, Y_test, verbose=0)
predictions = model3.predict(Xtest)
confusion  = confusion_matrix(Y_test.argmax(axis=1), predictions.argmax(axis=1))
plt.figure(figsize = (5,5))
sns.heatmap(confusion,square=False,annot=True,cbar=False,fmt='d')
plt.xlabel('predicted value')
plt.ylabel('true value')
plt.show()
testreal = model3.predict(real)
print(testreal.argmax(axis=1))
# Out:
# (31999, 12)
# Epoch 1/120
# 31999/31999 [==============================] - 12s 385us/step - loss: 2.1002 - acc: 0.2323
# Epoch 2/120
# 31999/31999 [==============================] - 12s 365us/step - loss: 1.7412 - acc: 0.3484
# Epoch 3/120
# 31999/31999 [==============================] - 12s 367us/step - loss: 1.4835 - acc: 0.4360
# Epoch 4/120
# 31999/31999 [==============================] - 12s 366us/step - loss: 1.3140 - acc: 0.4939
# Epoch 5/120
# 31999/31999 [==============================] - 12s 365us/step - loss: 1.2125 - acc: 0.5265
# Epoch 6/120
# 31999/31999 [==============================] - 12s 387us/step - loss: 1.1332 - acc: 0.5537
# Epoch 7/120
# 31999/31999 [==============================] - 14s 436us/step - loss: 1.0768 - acc: 0.57702
# Epoch 8/120
# 31999/31999 [==============================] - 12s 376us/step - loss: 1.0471 - acc: 0.5899
# Epoch 9/120
# 31999/31999 [==============================] - 12s 371us/step - loss: 1.0074 - acc: 0.6015
# Epoch 10/120
# 31999/31999 [==============================] - 12s 376us/step - loss: 0.9750 - acc: 0.6168
# Epoch 11/120
# 31999/31999 [==============================] - 13s 396us/step - loss: 0.9478 - acc: 0.6287
# Epoch 12/120
# 31999/31999 [==============================] - 12s 382us/step - loss: 0.9198 - acc: 0.6343
# Epoch 13/120
# 31999/31999 [==============================] - 12s 379us/step - loss: 0.9033 - acc: 0.6456
# Epoch 14/120
# 31999/31999 [==============================] - 13s 391us/step - loss: 0.8826 - acc: 0.6516
# Epoch 15/120
# 31999/31999 [==============================] - 13s 393us/step - loss: 0.8794 - acc: 0.6581
